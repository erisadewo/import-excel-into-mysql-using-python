# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('retail.csv')

# %%
df.head(3)
# Out:
#       Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0  Art & Sculpture            34      14935.0     -594.0  -1609.0
# 1           Basket            13       3744.0     -316.8      0.0
# 2           Basket            12       3825.0     -201.6   -288.0
#
#    Total Net Sales
# 0          12732.0
# 1           3427.2
# 2           3335.4

# %%
df.dtypes
# Out:
# Product Type        object
# Net Quantity         int64
# Gross Sales        float64
# Discounts          float64
# Returns            float64
# Total Net Sales    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Product Type       8
# Net Quantity       0
# Gross Sales        0
# Discounts          0
# Returns            0
# Total Net Sales    0
# dtype: int64

# %%
df.fillna(0, inplace = True)

# %%
df.isna().sum()
# Out:
# Product Type       0
# Net Quantity       0
# Gross Sales        0
# Discounts          0
# Returns            0
# Total Net Sales    0
# dtype: int64

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', user='root',  
                        password='Rahasiadon9')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE A")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='Exercise', user='root', password='Rahasiadon9')
    df = pd.read_csv('retail.csv')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS retail;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE Retail(Product_Type Varchar(255), Net_Quantity Varchar(255), Gross_Sales int, Discount int, Returns int, Total_Net_Sales int)")
        print("Table is created....")
        #loop through the data frame
        for i,row in df.iterrows():
            #here %S means string values 
            sql = "INSERT INTO A.Retail VALUES (%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('a',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
# Execute query
sql = "SELECT * FROM A.Retail"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('Art & Sculpture', '34', 14935, -594, -1609, 12732)
# ('Basket', '13', 3744, -317, 0, 3427)
# ('Basket', '12', 3825, -202, -288, 3335)
# ('Basket', '17', 3035, -63, 0, 2972)
# ('Art & Sculpture', '47', 2697, -44, 0, 2653)
# ('Basket', '17', 2695, -53, -110, 2533)
# ('Basket', '20', 2310, -66, -110, 2134)
# ('Christmas', '90', 2160, -46, 0, 2114)
# ('Art & Sculpture', '10', 2250, -180, 0, 2070)
# ('Basket', '11', 1925, -18, 0, 1908)
# ('Basket', '30', 1907, -41, 0, 1866)
# ('Home Decor', '19', 1748, -47, 0, 1701)
# ('Basket', '15', 1725, -92, 0, 1633)
# ('Art & Sculpture', '2', 1625, -5, 0, 1620)
# ('Recycled Art', '37', 1554, -29, 0, 1525)
# ('Jewelry', '33', 1584, -67, 0, 1517)
# ('Basket', '20', 1560, -48, 0, 1512)
# ('Jewelry', '32', 1536, -77, 0, 1459)
# ('Home Decor', '17', 1496, -44, 0, 1452)
# ('Basket', '5', 1467, -58, 0, 1409)
# ('Art & Sculpture', '9', 1466, -76, 0, 1390)
# ('Art & Sculpture', '11', 1375, -13, 0, 1363)
# ('Art & Sculpture', '58', 1392, -36, 0, 1356)
# ...
